# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Jun  7 12:52:01 2019

@author: wesleyz
"""
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import pandas as pd 
from sklearn import preprocessing

path = os.getcwd() # my actual path    
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 


#"features-harem-cd-1.csv"
#"labels-harem-cd-1.csv"

filedata = path + '/features-NER-20-portarias_treino.csv'
fileLabel = path + '/labels-names-NER-20-portarias_treino.csv'
fullfile = path + '/full-NER-20-portarias_treino.csv'

#data = pd.read_csv("features-harem-cd-1.csv") 
data = pd.read_csv(filedata) 
label = pd.read_csv(fileLabel) 
fulldata = pd.read_csv(fullfile) 



def classifica(df, k):
    bench = []
    # Preview the first 5 lines of the loaded data 
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(df.loc[:, df.columns != 'label'], fulldata.label, test_size=0.20, random_state=42)
    maxi = []
    print('B_PESSOA-------------------------------------')
    for i in range(2,k,1):
        
        fig = plt.figure()    
        for j in  ['precision', 'recall', 'f1-score']: #['precision']:
            
            clf = neighbors.KNeighborsClassifier(i, n_jobs = 20)
            clf.fit(X_train,y_train)
            #clf.fit(df.loc[df['label'] == 2], df.loc[df['label'] == 2].label)
            y_pred = clf.predict(X_test)        
            #y_pred = clf.predict(fulldata.loc[:, fulldata.columns != 'label'])        
            cr = classification_report(y_test, y_pred, output_dict=True)
            
            #bench.append((i, cr['I_PESSOA'][j], 'j'))        
            bench.append((j, i, cr['2'][j]))
            
            
        #benc = pd.DataFrame(bench, columns=['k', 'valor', 'metrica',])
        #aux = benc.loc[benc['valor'] == benc.valor.max()],  benc.valor.max()
        #maxi.append((j, benc.valor.max(), aux))
        #benc.hist()
        #ax = plt.axes()
        #ax.plot(benc.k, benc.valor, label = j);
        #plt.legend()
        #plt.show()
        
    
    return bench
    


from sklearn.metrics.pairwise import cosine_similarity

from sklearn import preprocessing

df = fulldata

# Get column names first
names = df.columns
# Create the Scaler object
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=names)

df = scaled_df

cosimi = cosine_similarity(scaled_df)

dfS = pd.DataFrame(scaled_df)


cosimi.sort(axis=0)
cosimi.sort(axis=1)




metrics = classifica(scaled_df, 100)
from numpy import linalg as LA
w, v = LA.eigh(scaled_df.cov())
wS = pd.Series(w)
wS.hist()
#v.shape
#w.shape
df5 = pd.DataFrame(w)
#df5 = pd.DataFrame(v)

#df.cov()

plt.matshow(cosimi)
plt.show()
# Out:
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# B_PESSOA-------------------------------------
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /media/wesleyz/HD1Tera/anacond3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# metr = pd.DataFrame(metrics, columns=['metrica', 'k', 'valor',])

# %% [markdown]
# print(metr)

# %%
import seaborn as sns
metr = pd.DataFrame(metrics, columns=['metrica', 'k', 'score',])


pivot = metr.pivot_table(index=[ 'k', ], columns=['metrica'],fill_value=0,  aggfunc=['mean'])

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt


sns.set(style="ticks", color_codes=True)


#kind="count"
#sns.catplot(x="k", y="valor", kind="violin", data=metr, hue="metrica");
ax = sns.lineplot(x="k", y="score", hue="metrica", data=metr);

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans
import sklearn.metrics as mt

bench2 = []
for i in range(2,200, 1):
    true_k = i
    km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', n_init=1,
                             init_size=1000, batch_size=1000)
    print("Clustering sparse data with %s" % km)
    labels = label.label.values #label.values #fulldata.label
    km.fit(df)
    print("done in %0.3fs")
    print()

    print("Homogeneity: %0.3f" % mt.homogeneity_score(labels, km.labels_))
    print("Completeness: %0.3f" % mt.completeness_score(labels, km.labels_))
    print("V-measure: %0.3f" % mt.v_measure_score(labels, km.labels_))
    print("Adjusted Rand-Index: %.3f"
          % mt.adjusted_rand_score(labels, km.labels_))
    print("Silhouette Coefficient: %0.3f"
          % mt.silhouette_score(df, km.labels_, sample_size=1000))

    print()
    bench2.append(('Homogeneity',i, mt.homogeneity_score(labels, km.labels_)))
    bench2.append(('Completeness',i, mt.completeness_score(labels, km.labels_)))
    bench2.append(('V-measure',i, mt.v_measure_score(labels, km.labels_)))
    bench2.append(('Adjusted Rand-Index',i, mt.adjusted_rand_score(labels, km.labels_)))
    bench2.append(('Silhouette Coefficient:',i, mt.silhouette_score(df, km.labels_, sample_size=1000)))

    
    
bench2
metr2 = pd.DataFrame(bench2, columns=['metrica', 'k', 'valor',])
metr2


import seaborn as sns; sns.set()
import matplotlib.pyplot as plt


sns.set(style="ticks", color_codes=True)


#kind="count"
#sns.catplot(x="k", y="valor", kind="violin", data=metr, hue="metrica");
ax = sns.lineplot(x="k", y="valor", hue="metrica", data=metr2);
# Out:
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=2,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.083
# Completeness: 0.140
# V-measure: 0.104
# Adjusted Rand-Index: -0.004
# Silhouette Coefficient: 0.115
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=3,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.118
# Completeness: 0.138
# V-measure: 0.127
# Adjusted Rand-Index: -0.086
# Silhouette Coefficient: 0.112
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=4,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.198
# Completeness: 0.171
# V-measure: 0.183
# Adjusted Rand-Index: 0.005
# Silhouette Coefficient: 0.151
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=5,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.259
# Completeness: 0.186
# V-measure: 0.217
# Adjusted Rand-Index: 0.104
# Silhouette Coefficient: 0.153
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=6,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.292
# Completeness: 0.200
# V-measure: 0.237
# Adjusted Rand-Index: 0.051
# Silhouette Coefficient: 0.162
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=7,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.355
# Completeness: 0.219
# V-measure: 0.271
# Adjusted Rand-Index: 0.062
# Silhouette Coefficient: 0.172
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=8,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.348
# Completeness: 0.195
# V-measure: 0.250
# Adjusted Rand-Index: 0.074
# Silhouette Coefficient: 0.152
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=9,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.336
# Completeness: 0.187
# V-measure: 0.240
# Adjusted Rand-Index: 0.006
# Silhouette Coefficient: 0.166
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=10,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.389
# Completeness: 0.196
# V-measure: 0.261
# Adjusted Rand-Index: 0.041
# Silhouette Coefficient: 0.161
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=11,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.377
# Completeness: 0.187
# V-measure: 0.250
# Adjusted Rand-Index: 0.043
# Silhouette Coefficient: 0.164
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=12,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.363
# Completeness: 0.173
# V-measure: 0.234
# Adjusted Rand-Index: 0.021
# Silhouette Coefficient: 0.156
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=13,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.463
# Completeness: 0.216
# V-measure: 0.295
# Adjusted Rand-Index: 0.044
# Silhouette Coefficient: 0.142
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=14,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.487
# Completeness: 0.218
# V-measure: 0.301
# Adjusted Rand-Index: 0.065
# Silhouette Coefficient: 0.150
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=15,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.416
# Completeness: 0.184
# V-measure: 0.255
# Adjusted Rand-Index: 0.058
# Silhouette Coefficient: 0.155
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=16,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.485
# Completeness: 0.206
# V-measure: 0.289
# Adjusted Rand-Index: 0.058
# Silhouette Coefficient: 0.174
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=17,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.508
# Completeness: 0.210
# V-measure: 0.297
# Adjusted Rand-Index: 0.047
# Silhouette Coefficient: 0.150
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=18,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.465
# Completeness: 0.190
# V-measure: 0.269
# Adjusted Rand-Index: 0.047
# Silhouette Coefficient: 0.146
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=19,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.430
# Completeness: 0.171
# V-measure: 0.244
# Adjusted Rand-Index: 0.020
# Silhouette Coefficient: 0.162
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=20,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.489
# Completeness: 0.190
# V-measure: 0.273
# Adjusted Rand-Index: 0.028
# Silhouette Coefficient: 0.149
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=21,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.476
# Completeness: 0.186
# V-measure: 0.267
# Adjusted Rand-Index: 0.032
# Silhouette Coefficient: 0.146
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=22,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.511
# Completeness: 0.196
# V-measure: 0.283
# Adjusted Rand-Index: 0.038
# Silhouette Coefficient: 0.154
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=23,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.511
# Completeness: 0.190
# V-measure: 0.277
# Adjusted Rand-Index: 0.035
# Silhouette Coefficient: 0.150
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=24,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.507
# Completeness: 0.186
# V-measure: 0.272
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.160
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=25,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.572
# Completeness: 0.217
# V-measure: 0.314
# Adjusted Rand-Index: 0.044
# Silhouette Coefficient: 0.174
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=26,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.517
# Completeness: 0.187
# V-measure: 0.274
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.165
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=27,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.495
# Completeness: 0.176
# V-measure: 0.260
# Adjusted Rand-Index: 0.033
# Silhouette Coefficient: 0.153
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=28,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.479
# Completeness: 0.169
# V-measure: 0.250
# Adjusted Rand-Index: 0.020
# Silhouette Coefficient: 0.149
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=29,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.511
# Completeness: 0.178
# V-measure: 0.264
# Adjusted Rand-Index: 0.024
# Silhouette Coefficient: 0.164
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=30,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.508
# Completeness: 0.176
# V-measure: 0.262
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.174
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=31,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.565
# Completeness: 0.195
# V-measure: 0.289
# Adjusted Rand-Index: 0.022
# Silhouette Coefficient: 0.177
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=32,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.539
# Completeness: 0.183
# V-measure: 0.273
# Adjusted Rand-Index: 0.022
# Silhouette Coefficient: 0.158
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=33,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.608
# Completeness: 0.206
# V-measure: 0.308
# Adjusted Rand-Index: 0.032
# Silhouette Coefficient: 0.180
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=34,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.572
# Completeness: 0.193
# V-measure: 0.289
# Adjusted Rand-Index: 0.027
# Silhouette Coefficient: 0.176
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=35,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.562
# Completeness: 0.185
# V-measure: 0.278
# Adjusted Rand-Index: 0.026
# Silhouette Coefficient: 0.174
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=36,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.566
# Completeness: 0.189
# V-measure: 0.284
# Adjusted Rand-Index: 0.026
# Silhouette Coefficient: 0.179
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=37,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.616
# Completeness: 0.199
# V-measure: 0.301
# Adjusted Rand-Index: 0.032
# Silhouette Coefficient: 0.185
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=38,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.520
# Completeness: 0.168
# V-measure: 0.254
# Adjusted Rand-Index: 0.016
# Silhouette Coefficient: 0.179
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=39,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.545
# Completeness: 0.173
# V-measure: 0.263
# Adjusted Rand-Index: 0.022
# Silhouette Coefficient: 0.181
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=40,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.550
# Completeness: 0.175
# V-measure: 0.266
# Adjusted Rand-Index: 0.024
# Silhouette Coefficient: 0.187
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=41,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.570
# Completeness: 0.180
# V-measure: 0.274
# Adjusted Rand-Index: 0.024
# Silhouette Coefficient: 0.178
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=42,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.563
# Completeness: 0.175
# V-measure: 0.267
# Adjusted Rand-Index: 0.020
# Silhouette Coefficient: 0.174
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=43,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.563
# Completeness: 0.174
# V-measure: 0.266
# Adjusted Rand-Index: 0.018
# Silhouette Coefficient: 0.198
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=44,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.589
# Completeness: 0.182
# V-measure: 0.278
# Adjusted Rand-Index: 0.020
# Silhouette Coefficient: 0.191
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=45,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.622
# Completeness: 0.190
# V-measure: 0.291
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.185
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=46,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.639
# Completeness: 0.196
# V-measure: 0.300
# Adjusted Rand-Index: 0.024
# Silhouette Coefficient: 0.204
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=47,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.569
# Completeness: 0.175
# V-measure: 0.268
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.185
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=48,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.644
# Completeness: 0.195
# V-measure: 0.300
# Adjusted Rand-Index: 0.021
# Silhouette Coefficient: 0.199
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=49,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.628
# Completeness: 0.190
# V-measure: 0.292
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.183
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=50,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.651
# Completeness: 0.198
# V-measure: 0.304
# Adjusted Rand-Index: 0.027
# Silhouette Coefficient: 0.204
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=51,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.634
# Completeness: 0.188
# V-measure: 0.290
# Adjusted Rand-Index: 0.022
# Silhouette Coefficient: 0.185
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=52,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.658
# Completeness: 0.194
# V-measure: 0.300
# Adjusted Rand-Index: 0.022
# Silhouette Coefficient: 0.210
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=53,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.649
# Completeness: 0.192
# V-measure: 0.296
# Adjusted Rand-Index: 0.024
# Silhouette Coefficient: 0.194
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=54,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.682
# Completeness: 0.198
# V-measure: 0.308
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.206
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=55,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.656
# Completeness: 0.193
# V-measure: 0.298
# Adjusted Rand-Index: 0.021
# Silhouette Coefficient: 0.213
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=56,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.639
# Completeness: 0.185
# V-measure: 0.287
# Adjusted Rand-Index: 0.018
# Silhouette Coefficient: 0.195
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=57,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.699
# Completeness: 0.202
# V-measure: 0.314
# Adjusted Rand-Index: 0.025
# Silhouette Coefficient: 0.211
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=58,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.646
# Completeness: 0.187
# V-measure: 0.290
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.212
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=59,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.683
# Completeness: 0.196
# V-measure: 0.304
# Adjusted Rand-Index: 0.021
# Silhouette Coefficient: 0.193
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=60,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.681
# Completeness: 0.196
# V-measure: 0.305
# Adjusted Rand-Index: 0.023
# Silhouette Coefficient: 0.207
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=61,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.670
# Completeness: 0.190
# V-measure: 0.296
# Adjusted Rand-Index: 0.019
# Silhouette Coefficient: 0.204
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=62,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.652
# Completeness: 0.186
# V-measure: 0.289
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.223
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=63,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.661
# Completeness: 0.188
# V-measure: 0.292
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.218
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=64,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.685
# Completeness: 0.194
# V-measure: 0.302
# Adjusted Rand-Index: 0.021
# Silhouette Coefficient: 0.216
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=65,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.679
# Completeness: 0.190
# V-measure: 0.297
# Adjusted Rand-Index: 0.018
# Silhouette Coefficient: 0.220
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=66,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.670
# Completeness: 0.189
# V-measure: 0.295
# Adjusted Rand-Index: 0.019
# Silhouette Coefficient: 0.225
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=67,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.674
# Completeness: 0.187
# V-measure: 0.293
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.208
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=68,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.695
# Completeness: 0.192
# V-measure: 0.301
# Adjusted Rand-Index: 0.019
# Silhouette Coefficient: 0.212
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=69,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.681
# Completeness: 0.188
# V-measure: 0.295
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.237
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=70,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.716
# Completeness: 0.198
# V-measure: 0.311
# Adjusted Rand-Index: 0.022
# Silhouette Coefficient: 0.220
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=71,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.716
# Completeness: 0.196
# V-measure: 0.308
# Adjusted Rand-Index: 0.018
# Silhouette Coefficient: 0.235
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=72,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.706
# Completeness: 0.195
# V-measure: 0.306
# Adjusted Rand-Index: 0.020
# Silhouette Coefficient: 0.226
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=73,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.684
# Completeness: 0.187
# V-measure: 0.294
# Adjusted Rand-Index: 0.018
# Silhouette Coefficient: 0.224
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=74,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.699
# Completeness: 0.190
# V-measure: 0.299
# Adjusted Rand-Index: 0.016
# Silhouette Coefficient: 0.235
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=75,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.701
# Completeness: 0.191
# V-measure: 0.301
# Adjusted Rand-Index: 0.019
# Silhouette Coefficient: 0.210
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=76,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.710
# Completeness: 0.194
# V-measure: 0.304
# Adjusted Rand-Index: 0.019
# Silhouette Coefficient: 0.235
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=77,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.684
# Completeness: 0.185
# V-measure: 0.291
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.238
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=78,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.712
# Completeness: 0.190
# V-measure: 0.300
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.212
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=79,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.717
# Completeness: 0.192
# V-measure: 0.302
# Adjusted Rand-Index: 0.018
# Silhouette Coefficient: 0.239
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=80,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.703
# Completeness: 0.188
# V-measure: 0.297
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.218
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=81,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.702
# Completeness: 0.188
# V-measure: 0.296
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.221
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=82,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.692
# Completeness: 0.183
# V-measure: 0.289
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.229
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=83,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.720
# Completeness: 0.190
# V-measure: 0.301
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.234
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=84,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.703
# Completeness: 0.187
# V-measure: 0.296
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.231
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=85,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.732
# Completeness: 0.195
# V-measure: 0.308
# Adjusted Rand-Index: 0.016
# Silhouette Coefficient: 0.240
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=86,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.689
# Completeness: 0.183
# V-measure: 0.289
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.231
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=87,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.715
# Completeness: 0.188
# V-measure: 0.298
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.216
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=88,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.729
# Completeness: 0.191
# V-measure: 0.303
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.257
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=89,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.738
# Completeness: 0.195
# V-measure: 0.309
# Adjusted Rand-Index: 0.017
# Silhouette Coefficient: 0.228
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=90,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.704
# Completeness: 0.185
# V-measure: 0.293
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.253
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=91,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.710
# Completeness: 0.184
# V-measure: 0.292
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.242
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=92,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.720
# Completeness: 0.186
# V-measure: 0.296
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.242
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=93,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.746
# Completeness: 0.193
# V-measure: 0.307
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.259
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=94,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.709
# Completeness: 0.183
# V-measure: 0.290
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.263
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=95,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.723
# Completeness: 0.187
# V-measure: 0.296
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.238
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=96,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.730
# Completeness: 0.188
# V-measure: 0.299
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.259
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=97,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.732
# Completeness: 0.187
# V-measure: 0.298
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.249
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=98,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.736
# Completeness: 0.188
# V-measure: 0.300
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.254
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=99,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.734
# Completeness: 0.188
# V-measure: 0.299
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.256
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=100, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.726
# Completeness: 0.187
# V-measure: 0.297
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.246
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=101, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.728
# Completeness: 0.187
# V-measure: 0.298
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.245
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=102, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.728
# Completeness: 0.184
# V-measure: 0.293
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.262
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=103, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.717
# Completeness: 0.184
# V-measure: 0.292
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.256
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=104, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.735
# Completeness: 0.186
# V-measure: 0.297
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.258
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=105, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.750
# Completeness: 0.189
# V-measure: 0.302
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.263
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=106, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.737
# Completeness: 0.186
# V-measure: 0.297
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.248
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=107, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.728
# Completeness: 0.183
# V-measure: 0.293
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.266
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=108, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.751
# Completeness: 0.189
# V-measure: 0.302
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.274
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=109, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.720
# Completeness: 0.180
# V-measure: 0.288
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.257
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=110, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.739
# Completeness: 0.186
# V-measure: 0.297
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.262
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=111, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.751
# Completeness: 0.187
# V-measure: 0.300
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.274
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=112, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.743
# Completeness: 0.185
# V-measure: 0.296
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.259
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=113, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.761
# Completeness: 0.190
# V-measure: 0.304
# Adjusted Rand-Index: 0.015
# Silhouette Coefficient: 0.270
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=114, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.745
# Completeness: 0.186
# V-measure: 0.297
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.260
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=115, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.761
# Completeness: 0.189
# V-measure: 0.303
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.262
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=116, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.730
# Completeness: 0.182
# V-measure: 0.291
# Adjusted Rand-Index: 0.012
# Silhouette Coefficient: 0.268
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=117, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.754
# Completeness: 0.186
# V-measure: 0.298
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.277
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=118, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.758
# Completeness: 0.186
# V-measure: 0.299
# Adjusted Rand-Index: 0.012
# Silhouette Coefficient: 0.263
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=119, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.754
# Completeness: 0.185
# V-measure: 0.297
# Adjusted Rand-Index: 0.012
# Silhouette Coefficient: 0.276
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=120, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.745
# Completeness: 0.183
# V-measure: 0.294
# Adjusted Rand-Index: 0.012
# Silhouette Coefficient: 0.274
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=121, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.768
# Completeness: 0.187
# V-measure: 0.301
# Adjusted Rand-Index: 0.013
# Silhouette Coefficient: 0.276
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=122, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.763
# Completeness: 0.188
# V-measure: 0.302
# Adjusted Rand-Index: 0.014
# Silhouette Coefficient: 0.251
#
# ...
#
# Homogeneity: 0.803
# Completeness: 0.187
# V-measure: 0.304
# Adjusted Rand-Index: 0.012
# Silhouette Coefficient: 0.306
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=160, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.816
# Completeness: 0.189
# V-measure: 0.307
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.334
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=161, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.793
# Completeness: 0.183
# V-measure: 0.298
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.292
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=162, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.803
# Completeness: 0.187
# V-measure: 0.303
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.282
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=163, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.791
# Completeness: 0.184
# V-measure: 0.299
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.306
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=164, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.776
# Completeness: 0.179
# V-measure: 0.291
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.304
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=165, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.810
# Completeness: 0.187
# V-measure: 0.303
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.307
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=166, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.791
# Completeness: 0.183
# V-measure: 0.297
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.289
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=167, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.809
# Completeness: 0.187
# V-measure: 0.304
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.303
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=168, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.796
# Completeness: 0.184
# V-measure: 0.298
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.305
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=169, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.806
# Completeness: 0.187
# V-measure: 0.304
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.311
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=170, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.809
# Completeness: 0.186
# V-measure: 0.302
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.314
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=171, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.805
# Completeness: 0.185
# V-measure: 0.300
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.297
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=172, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.795
# Completeness: 0.182
# V-measure: 0.296
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.302
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=173, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.815
# Completeness: 0.187
# V-measure: 0.304
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.299
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=174, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.812
# Completeness: 0.186
# V-measure: 0.303
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.301
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=175, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.807
# Completeness: 0.186
# V-measure: 0.302
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.296
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=176, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.795
# Completeness: 0.181
# V-measure: 0.295
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.283
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=177, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.806
# Completeness: 0.183
# V-measure: 0.299
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.311
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=178, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.797
# Completeness: 0.182
# V-measure: 0.296
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.305
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=179, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.805
# Completeness: 0.184
# V-measure: 0.299
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.300
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=180, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.822
# Completeness: 0.187
# V-measure: 0.305
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.328
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=181, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.825
# Completeness: 0.188
# V-measure: 0.306
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.291
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=182, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.804
# Completeness: 0.182
# V-measure: 0.297
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.316
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=183, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.810
# Completeness: 0.184
# V-measure: 0.300
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.298
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=184, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.819
# Completeness: 0.185
# V-measure: 0.302
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.303
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=185, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.790
# Completeness: 0.181
# V-measure: 0.294
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.298
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=186, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.813
# Completeness: 0.183
# V-measure: 0.299
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.304
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=187, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.837
# Completeness: 0.191
# V-measure: 0.311
# Adjusted Rand-Index: 0.011
# Silhouette Coefficient: 0.325
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=188, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.812
# Completeness: 0.184
# V-measure: 0.301
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.294
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=189, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.803
# Completeness: 0.181
# V-measure: 0.295
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.326
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=190, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.811
# Completeness: 0.183
# V-measure: 0.299
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.314
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=191, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.804
# Completeness: 0.182
# V-measure: 0.297
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.317
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=192, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.817
# Completeness: 0.185
# V-measure: 0.302
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.294
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=193, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.810
# Completeness: 0.183
# V-measure: 0.299
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.308
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=194, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.820
# Completeness: 0.184
# V-measure: 0.301
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.306
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=195, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.825
# Completeness: 0.185
# V-measure: 0.303
# Adjusted Rand-Index: 0.010
# Silhouette Coefficient: 0.323
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=196, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.823
# Completeness: 0.185
# V-measure: 0.302
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.326
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=197, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.818
# Completeness: 0.183
# V-measure: 0.299
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.330
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=198, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.822
# Completeness: 0.185
# V-measure: 0.302
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.297
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10,
#         n_clusters=199, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)
# done in %0.3fs
#
# Homogeneity: 0.813
# Completeness: 0.182
# V-measure: 0.297
# Adjusted Rand-Index: 0.009
# Silhouette Coefficient: 0.321
